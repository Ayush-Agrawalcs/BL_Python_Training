# %%
import pandas as pd

# %%
pd.__version__
# Out:
# '3.0.1'

# %%
# series

sales=pd.Series([1,2,3,0])
sales
# Out:
# 0    1
# 1    2
# 2    3
# 3    0
# dtype: int64

# %%
p=sales[0]
p
# Out:
# np.int64(1)

# %%
sales[0:2:]
# Out:
# 0    1
# 1    2
# dtype: int64

# %%
sales.index
# Out:
# RangeIndex(start=0, stop=4, step=1)

# %%
sales.values
# Out:
# array([1, 2, 3, 0])

# %%
sales.dtype
# Out:
# dtype('int64')

# %%
sales.head(2)
# Out:
# 0    1
# 1    2
# dtype: int64

# %%
sales.tail(1)
# Out:
# 3    0
# dtype: int64

# %%
sales.sort_values()
# Out:
# 3    0
# 0    1
# 1    2
# 2    3
# dtype: int64

# %%
sales.count()
# Out:
# np.int64(4)

# %%
sales.isnull()
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# dtype: bool

# %%
sales.notnull()
# Out:
# 0    True
# 1    True
# 2    True
# 3    True
# dtype: bool

# %%
sales + 1
# Out:
# 0    2
# 1    3
# 2    4
# 3    1
# dtype: int64

# %%
sales *2
# Out:
# 0    2
# 1    4
# 2    6
# 3    0
# dtype: int64

# %%
s=pd.Series([1,None,5])
s.isnull()
# Out:
# 0    False
# 1     True
# 2    False
# dtype: bool

# %%
k=s.fillna(0)
k
# Out:
# 0    1.0
# 1    0.0
# 2    5.0
# dtype: float64

# %%
s1=pd.Series(data=[100,200,300,400,500],index=list('abcde'))
s1
# Out:
# a    100
# b    200
# c    300
# d    400
# e    500
# dtype: int64

# %%
data=pd.DataFrame({
    'Name':['Anna','Ben'],
    'Lemonades':[2,3]
})
data
# Out:
#    Name  Lemonades
# 0  Anna          2
# 1   Ben          3

# %%
s1=pd.Series([1,2,3,4,5])
s2=pd.Series([10,20,30,40,50])
data=pd.DataFrame({'C1':s1 , 'C2':s2})
data
# Out:
#    C1  C2
# 0   1  10
# 1   2  20
# 2   3  30
# 3   4  40
# 4   5  50

# %%
data.shape
# Out:
# (5, 2)

# %%
data.columns
# Out:
# Index(['C1', 'C2'], dtype='str')

# %%
data.dtypes
# Out:
# C1    int64
# C2    int64
# dtype: object

# %%
# using labels
data.loc[1,'C1']

#using index
data.iloc[1,0]
# Out:
# np.int64(2)

# %%
#data information
data.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   C1      5 non-null      int64
#  1   C2      5 non-null      int64
# dtypes: int64(2)
# memory usage: 212.0 bytes

# %%
# data describe
data.describe()
# Out:
#              C1         C2
# count  5.000000   5.000000
# mean   3.000000  30.000000
# std    1.581139  15.811388
# min    1.000000  10.000000
# 25%    2.000000  20.000000
# 50%    3.000000  30.000000
# 75%    4.000000  40.000000
# max    5.000000  50.000000

# %%
# Filtering
data[data['C1']>=2]
# Out:
#    C1  C2
# 1   2  20
# 2   3  30
# 3   4  40
# 4   5  50

# %%
# add newcolumn
data['Tips']=[10,20,30,40,40]
data
# Out:
#    C1  C2  Tips
# 0   1  10    10
# 1   2  20    20
# 2   3  30    30
# 3   4  40    40
# 4   5  50    40

# %%
#updating
data.loc[data['C1']==4]=10
data
# Out:
#    C1  C2  Tips
# 0   1  10    10
# 1  10  10    10
# 2   3  30    30
# 3  10  10    10
# 4   5  50    40

# %%
data.rename(columns={"C1":"column1"},inplace=True)
data
# Out:
#    column1  C2  Tips
# 0        1  10    10
# 1       10  10    10
# 2        3  30    30
# 3       10  10    10
# 4        5  50    40

# %%
data.set_index('C2',inplace=True)

# %%
data
# Out:
#     Tips
# C2
# 10    10
# 10    10
# 30    30
# 10    10
# 50    40
